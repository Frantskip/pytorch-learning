# %%
import torch
import numpy as np

# %%
tensor1= torch.tensor([1,2,3])
print(tensor1)
print(tensor1.dtype)
# Out:
# tensor([1, 2, 3])
# torch.int64

# %%
tensor1 = tensor1.type(torch.float32)
print(tensor1)
print(tensor1.dtype)
# Out:
# tensor([1., 2., 3.])
# torch.float32
